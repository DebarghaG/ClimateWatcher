# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, Imputer
import keras
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
# Out:
# /usr/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# Using TensorFlow backend.

# %%
filePath = "/home/debargha/Documents/ClimateWatcher/data.csv"

# %%
df = pd.read_csv(filePath, engine='python')
pf = df

# %%
df.rename(columns={'stn_code': 'station_code', 'location': 'city', 'location_monitoring_station': 'monitoring_station'}, inplace=True)
df.head()
# Out:
#   station_code       sampling_date           state       city agency  \
# 0          150  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 1          151  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 2          152  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 3          150     March - M031990  Andhra Pradesh  Hyderabad    NaN
# 4          151     March - M031990  Andhra Pradesh  Hyderabad    NaN
#
#                                  type  so2   no2  rspm  spm  \
# 0  Residential, Rural and other Areas  4.8  17.4   NaN  NaN
# 1                     Industrial Area  3.1   7.0   NaN  NaN
# 2  Residential, Rural and other Areas  6.2  28.5   NaN  NaN
# 3  Residential, Rural and other Areas  6.3  14.7   NaN  NaN
# 4                     Industrial Area  4.7   7.5   NaN  NaN
#
#   monitoring_station  pm2_5        date
# 0                NaN    NaN  1990-02-01
# 1                NaN    NaN  1990-02-01
# 2                NaN    NaN  1990-02-01
# 3                NaN    NaN  1990-03-01
# 4                NaN    NaN  1990-03-01

# %%
df['date'] = pd.to_datetime(df['date'],format='%Y-%m-%d') # date parse
df['date'] = df['date'].dt.year # year
df['type'].dropna(axis=0, inplace=True)

# %%
df.drop(df.columns[[0,1,4,8,9,10,11]], axis=1, inplace=True)

# %%
df
# Out:
#                               state       city  \
# 0                    Andhra Pradesh  Hyderabad
# 1                    Andhra Pradesh  Hyderabad
# 2                    Andhra Pradesh  Hyderabad
# 3                    Andhra Pradesh  Hyderabad
# 4                    Andhra Pradesh  Hyderabad
# 5                    Andhra Pradesh  Hyderabad
# 6                    Andhra Pradesh  Hyderabad
# 7                    Andhra Pradesh  Hyderabad
# 8                    Andhra Pradesh  Hyderabad
# 9                    Andhra Pradesh  Hyderabad
# 10                   Andhra Pradesh  Hyderabad
# 11                   Andhra Pradesh  Hyderabad
# 12                   Andhra Pradesh  Hyderabad
# 13                   Andhra Pradesh  Hyderabad
# 14                   Andhra Pradesh  Hyderabad
# 15                   Andhra Pradesh  Hyderabad
# 16                   Andhra Pradesh  Hyderabad
# 17                   Andhra Pradesh  Hyderabad
# 18                   Andhra Pradesh  Hyderabad
# 19                   Andhra Pradesh  Hyderabad
# 20                   Andhra Pradesh  Hyderabad
# 21                   Andhra Pradesh  Hyderabad
# 22                   Andhra Pradesh  Hyderabad
# 23                   Andhra Pradesh  Hyderabad
# 24                   Andhra Pradesh  Hyderabad
# 25                   Andhra Pradesh  Hyderabad
# 26                   Andhra Pradesh  Hyderabad
# 27                   Andhra Pradesh  Hyderabad
# 28                   Andhra Pradesh  Hyderabad
# 29                   Andhra Pradesh  Hyderabad
# ...                             ...        ...
# 435712                  West Bengal   ULUBERIA
# 435713                  West Bengal   ULUBERIA
# 435714                  West Bengal   ULUBERIA
# 435715                  West Bengal   ULUBERIA
# 435716                  West Bengal   ULUBERIA
# 435717                  West Bengal   ULUBERIA
# 435718                  West Bengal   ULUBERIA
# 435719                  West Bengal   ULUBERIA
# 435720                  West Bengal   ULUBERIA
# 435721                  West Bengal   ULUBERIA
# 435722                  West Bengal   ULUBERIA
# 435723                  West Bengal   ULUBERIA
# 435724                  West Bengal   ULUBERIA
# 435725                  West Bengal   ULUBERIA
# 435726                  West Bengal   ULUBERIA
# 435727                  West Bengal   ULUBERIA
# 435728                  West Bengal   ULUBERIA
# 435729                  West Bengal   ULUBERIA
# 435730                  West Bengal   ULUBERIA
# 435731                  West Bengal   ULUBERIA
# 435732                  West Bengal   ULUBERIA
# 435733                  West Bengal   ULUBERIA
# 435734                  West Bengal   ULUBERIA
# 435735                  West Bengal   ULUBERIA
# 435736                  West Bengal   ULUBERIA
# 435737                  West Bengal   ULUBERIA
# 435738                  West Bengal   ULUBERIA
# 435739  andaman-and-nicobar-isl
# 435735                               RIRUO  17.0  44.0  2015.0
# 435736                               RIRUO  18.0  45.0  2015.0
# 435737                               RIRUO  22.0  50.0  2015.0
# 435738                               RIRUO  20.0  46.0  2015.0
# 435739                                 NaN   NaN   NaN     NaN
# 435740                                 NaN   NaN   NaN     NaN
# 435741                                 NaN   NaN   NaN     NaN
#
# [435742 rows x 6 columns]

# %%
df.type.value_counts()
# Out:
# Residential, Rural and other Areas    179014
# Industrial Area                        96091
# Residential and others                 86791
# Industrial Areas                       51747
# Sensitive Area                          8980
# Sensitive Areas                         5536
# RIRUO                                   1304
# Sensitive                                495
# Industrial                               233
# Residential                              158
# Name: type, dtype: int64

# %%
df.type.replace(['Industrial Area', 'Industrial Areas' ,'Sensitive Areas', 'Sensitive Area'],['Industrial', 'Industrial', 'Sensitive', 'Sensitive'], inplace=True)

# %%
df.type.value_counts()
# Out:
# Residential, Rural and other Areas    179014
# Industrial                            148071
# Residential and others                 86791
# Sensitive                              15011
# RIRUO                                   1304
# Residential                              158
# Name: type, dtype: int64

# %%
encState = df.iloc[:,0]
encCity = df.iloc[:,1]
encType = df.iloc[:,2]

# %%
label_encoder = LabelEncoder()
encState = label_encoder.fit_transform(encState)
encType = label_encoder.fit_transform(encType.astype(str))
encCity = label_encoder.fit_transform(encCity.astype(str))

# %%
df['state'] = encState
df['city'] = encCity
df['type'] = encType

# %%
df.drop(df.columns[[4]], axis=1, inplace=True)

# %%
model = Sequential()
model.add(LSTM(input_shape=(435742,6),output_dim = 435742, return_sequences=True))
model.add(Dropout(0.5))
model.add(LSTM(435742))
model.add(Dropout(0.5))
model.add(Dense(2, activation='softmax'))
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
model.summary()
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:2: UserWarning: Update your `LSTM` call to the Keras 2 API: `LSTM(input_shape=(435742, 6..., return_sequences=True, units=435742)`
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-17-aac3f94eee6d> in <module>()
#       1 model = Sequential()
# ----> 2 model.add(LSTM(input_shape=(435742,6),output_dim = 435742, return_sequences=True))
#       3 model.add(Dropout(0.5))
#       4 model.add(LSTM(435742))
#       5 model.add(Dropout(0.5))
#
# /home/debargha/.local/lib/python3.6/site-packages/keras/engine/sequential.py in add(self, layer)
#     162                     # and create the node connecting the current layer
#     163                     # to the input layer we just created.
# --> 164                     layer(x)
#     165                     set_inputs = True
#     166                 else:
#
# /home/debargha/.local/lib/python3.6/site-packages/keras/layers/recurrent.py in __call__(self, inputs, initial_state, constants, **kwargs)
#     498
#     499         if initial_state is None and constants is None:
# --> 500             return super(RNN, self).__call__(inputs, **kwargs)
#     501
#     502         # If any of `initial_state` or `constants` are specified and are Keras
#
# /home/debargha/.local/lib/python3.6/site-packages/keras/engine/base_layer.py in __call__(self, inputs, **kwargs)
#     429                                          'You can build it manually via: '
#     430                                          '`layer.build(batch_input_shape)`')
# --> 431                 self.build(unpack_singleton(input_shapes))
#     432                 self.built = True
#     433
#
# /home/debargha/.local/lib/python3.6/site-packages/keras/layers/recurrent.py in build(self, input_shape)
#     459                 self.cell.build([step_input_shape] + constants_shape)
#     460             else:
# --> 461                 self.cell.build(step_input_shape)
#     462
#     463         # set or validate state_spec
#
# /home/debargha/.local/lib/python3.6/site-packages/keras/layers/recurrent.py in build(self, input_shape)
#    1803             initializer=self.recurrent_initializer,
#    1804             regularizer=self.recurrent_regularizer,
# -> 1805             constraint=self.recurrent_constraint)
#    1806
#    1807         if self.use_bias:
#
# /home/debargha/.local/lib/python3.6/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name +
#      90                               '` call to the Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# /home/debargha/.local/lib/python3.6/site-packages/keras/engine/base_layer.py in add_weight(self, name, shape, dtype, initializer, regularizer, trainable, constraint)
#     247         if dtype is None:
#     248             dtype = K.floatx()
# --> 249         weight = K.variable(initializer(shape),
#     250                             dtype=dtype,
#     251                             name=name,
#
# /home/debargha/.local/lib/python3.6/site-packages/keras/initializers.py in __call__(self, shape, dtype)
#     250         if self.seed is not None:
#     251             np.random.seed(self.seed)
# --> 252         a = np.random.normal(0.0, 1.0, flat_shape)
#     253         u, _, v = np.linalg.svd(a, full_matrices=False)
#     254         # Pick the one with the correct shape.
#
# mtrand.pyx in mtrand.RandomState.normal()
#
# mtrand.pyx in mtrand.cont2_array_sc()
#
# MemoryError:
